# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[ 8.6 ,  0.22,  0.36, ...,  3.47,  0.87, 11.  ],
#        [12.5 ,  0.46,  0.63, ...,  2.99,  0.87, 10.2 ],
#        [ 7.2 ,  0.54,  0.27, ...,  3.39,  0.71, 11.  ],
#        ...,
#        [ 7.2 ,  0.62,  0.06, ...,  3.51,  0.54,  9.5 ],
#        [ 7.9 ,  0.2 ,  0.35, ...,  3.32,  0.8 , 11.9 ],
#        [ 5.8 ,  0.29,  0.26, ...,  3.39,  0.54, 13.5 ]])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[-0.35676932,  0.26010529, -0.99737889, ..., -0.41107917,
#          0.02096782, -0.77477782],
#        [-0.30129498, -0.0901066 , -0.53147526, ...,  0.55616594,
#         -1.08367852, -0.86743843],
#        [ 1.30746073,  0.90216042, -0.2726399 , ..., -0.15314714,
#          1.98478355, -0.49679599],
#        ...,
#        [-0.91151266, -0.3235812 , -0.16910576, ...,  0.55616594,
#         -0.34724762,  0.15182827],
#        [ 1.19651206, -0.03173795,  1.90157706, ..., -1.37832427,
#          0.02096782,  1.26375557],
#        [ 0.86366605, -0.0901066 , -0.16910576, ...,  0.2337509 ,
#         -0.83820156, -0.40413538]])

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([5, 4, 5, 4, 6, 5, 5, 4, 6, 6, 7, 4, 6, 5, 6, 6, 6, 6, 7, 5, 5, 6,
#        5, 7, 6, 6, 7, 4, 6, 6, 6, 4, 6, 6, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5,
#        6, 6, 6, 5, 4, 5, 5, 5, 6, 6, 5, 4, 6, 5, 5, 5, 5, 5, 6, 6, 7, 5,
#        7, 6, 7, 5, 6, 5, 6, 6, 6, 5, 7, 5, 6, 6, 5, 7, 5, 6, 7, 6, 5, 6,
#        7, 5, 8, 6, 5, 5, 5, 6, 6, 6, 3, 5, 3, 5, 6, 6, 6, 7, 5, 5, 6, 5,
#        6, 5, 5, 5, 6, 6, 5, 5, 5, 6, 4, 6, 5, 6, 6, 5, 7, 5, 5, 6, 6, 7,
#        6, 7, 5, 5, 4, 6, 5, 7, 6, 7, 6, 5, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5,
#        6, 5, 5, 6, 5, 6, 7, 5, 6, 5, 6, 5, 5, 5, 5, 5, 5, 5, 7, 6, 7, 6,
#        6, 5, 5, 5, 5, 6, 7, 6, 5, 7, 6, 6, 7, 6, 6, 7, 4, 7, 5, 5, 6, 6,
#        5, 7, 5, 6, 6, 6, 6, 5, 5, 4, 7, 7, 8, 5, 5, 6, 7, 6, 6, 5, 6, 6,
#        6, 6, 8, 6, 4, 5, 5, 7, 5, 5, 5, 4, 6, 6, 5, 7, 5, 7, 6, 5, 5, 5,
#        6, 7, 6, 7, 5, 6, 7, 5, 5, 6, 6, 6, 6, 5, 6, 4, 5, 6, 7, 6, 5, 6,
#        5, 7, 5, 5, 6, 6, 5, 5, 5, 6, 6, 4, 6, 6, 6, 5, 7, 6, 5, 6, 5, 7,
#        5, 7, 5, 6, 5, 7, 8, 5, 5, 6, 5, 6, 7, 6, 5, 5, 6, 5, 6, 6, 6, 6,
#        4, 7, 4, 6, 4, 6, 6, 6, 5, 6, 6, 6, 6, 7, 6, 5, 5, 5, 6, 6, 4, 6,
#        6, 7, 5, 6, 6, 5, 6, 6, 5, 5, 7, 6, 5, 6, 6, 6, 6, 5, 6, 5, 7, 7,
#        5, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 6, 5,
#        5, 6, 6, 5, 5, 6, 6, 7, 7, 6, 5, 7, 5, 5, 6, 6, 5, 6, 6, 4, 6, 6,
#        6, 6, 6, 8, 5, 5, 6, 5, 7, 6, 7, 7, 6, 5, 5, 6, 6, 5, 6, 5, 5, 8,
#        6, 7, 6, 5, 6, 6, 5, 6, 5, 5, 6, 6, 7, 6, 6, 5, 7, 5, 5, 5, 5, 6,
#        6, 6, 6, 4, 5, 4, 6, 5, 6, 5, 7, 6, 5, 5, 5, 5, 7, 5, 6, 5, 5, 4,
#        5, 5, 6, 5, 6, 5, 5, 6, 7, 5, 5, 6, 5, 7, 8, 6, 7, 4])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score',accuracy_score(y_test,y_pred))
print('Confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score 0.5895833333333333
# Confusion matrix [[  0   1   0   0   0   0]
#  [  0   2   6   9   0   0]
#  [  2  12 129  45   7   0]
#  [  0  10  42 122  23   3]
#  [  0   0   3  26  29   3]
#  [  0   0   0   2   3   1]]

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
tree.plot_tree(dt,feature_names=['fixed acidity','fixed acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol'],filled=True)
# Out:
# [Text(0.5392262400580395, 0.9736842105263158, 'alcohol <= 0.102\nentropy = 1.71\nsamples = 1119\nvalue = [9, 36, 486, 438, 138, 12]'),
#  Text(0.36324934168099743, 0.9210526315789473, 'total sulfur dioxide <= 1.561\nentropy = 1.398\nsamples = 692\nvalue = [6, 25, 415, 219, 25, 2]'),
#  Text(0.20973170141874461, 0.868421052631579, 'sulphates <= -0.487\nentropy = 1.469\nsamples = 602\nvalue = [6, 24, 331, 215, 24, 2]'),
#  Text(0.08523215821152193, 0.8157894736842105, 'citric acid <= -1.102\nentropy = 1.358\nsamples = 234\nvalue = [4, 18, 156, 52, 4, 0]'),
#  Text(0.02235597592433362, 0.7631578947368421, 'sulphates <= -0.893\nentropy = 1.601\nsamples = 65\nvalue = [3, 7, 42, 9, 4, 0]'),
#  Text(0.006878761822871883, 0.7105263157894737, 'residual sugar <= -0.875\nentropy = 1.078\nsamples = 25\nvalue = [0, 7, 17, 0, 1, 0]'),
#  Text(0.0034393809114359416, 0.6578947368421053, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.010318142734307825, 0.6578947368421053, 'pH <= -0.255\nentropy = 0.871\nsamples = 24\nvalue = [0, 7, 17, 0, 0, 0]'),
#  Text(0.006878761822871883, 0.6052631578947368, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.013757523645743766, 0.6052631578947368, 'fixed acidity <= -0.239\nentropy = 0.989\nsamples = 16\nvalue = [0, 7, 9, 0, 0, 0]'),
#  Text(0.010318142734307825, 0.5526315789473685, 'free sulfur dioxide <= 0.008\nentropy = 0.89\nsamples = 13\nvalue = [0, 4, 9, 0, 0, 0]'),
#  Text(0.006878761822871883, 0.5, 'pH <= 0.232\nentropy = 0.684\nsamples = 11\nvalue = [0, 2, 9, 0, 0, 0]'),
#  Text(0.0034393809114359416, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.010318142734307825, 0.4473684210526316, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.013757523645743766, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.017196904557179708, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.037833190025795355, 0.7105263157894737, 'fixed acidity <= 0.34\nentropy = 1.469\nsamples = 40\nvalue = [3, 0, 25, 9, 3, 0]'),
#  Text(0.02407566638005159, 0.6578947368421053, 'total sulfur dioxide <= -0.771\nentropy = 1.435\nsamples = 11\nvalue = [0, 0, 2, 6, 3, 0]'),
#  Text(0.02063628546861565, 0.6052631578947368, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.027515047291487533, 0.6052631578947368, 'citric acid <= -1.255\nentropy = 0.811\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.02407566638005159, 0.5526315789473685, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.030954428202923472, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.051590713671539126, 0.6578947368421053, 'fixed acidity <= -0.327\nentropy = 0.942\nsamples = 29\nvalue = [3, 0, 23, 3, 0, 0]'),
#  Text(0.0412725709372313, 0.6052631578947368, 'fixed acidity <= 1.522\nentropy = 0.575\nsamples = 22\nvalue = [3, 0, 19, 0, 0, 0]'),
#  Text(0.037833190025795355, 0.5526315789473685, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.04471195184866724, 0.5526315789473685, 'alcohol <= -0.724\nentropy = 0.971\nsamples = 5\nvalue = [3, 0, 2, 0, 0, 0]'),
#  Text(0.0412725709372313, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.04815133276010318, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]'),
#  Text(0.061908856405846945, 0.6052631578947368, 'total sulfur dioxide <= -0.499\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.058469475494411005, 0.5526315789473685, 'chlorides <= 0.059\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.055030094582975066, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.061908856405846945, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06534823731728288, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.14810834049871024, 0.7631578947368421, 'density <= 2.132\nentropy = 1.186\nsamples = 169\nvalue = [1, 11, 114, 43, 0, 0]'),
#  Text(0.1446689595872743, 0.7105263157894737, 'alcohol <= -0.63\nentropy = 1.14\nsamples = 168\nvalue = [0, 11, 114, 43, 0, 0]'),
#  Text(0.09845227858985382, 0.6578947368421053, 'citric acid <= -0.385\nentropy = 0.953\nsamples = 107\nvalue = [0, 5, 82, 20, 0, 0]'),
#  Text(0.07910576096302666, 0.6052631578947368, 'residual sugar <= 1.157\nentropy = 0.89\nsamples = 39\nvalue = [0, 0, 27, 12, 0, 0]'),
#  Text(0.07566638005159071, 0.5526315789473685, 'free sulfur dioxide <= -0.82\nentropy = 0.811\nsamples = 36\nvalue = [0, 0, 27, 9, 0, 0]'),
#  Text(0.06878761822871883, 0.5, 'citric acid <= -0.692\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.06534823731728288, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.07222699914015478, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0825451418744626, 0.5, 'total sulfur dioxide <= -0.181\nentropy = 0.696\nsamples = 32\nvalue = [0, 0, 26, 6, 0, 0]'),
#  Text(0.07910576096302666, 0.4473684210526316, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.08598452278589853, 0.4473684210526316, 'total sulfur dioxide <= 0.077\nentropy = 0.881\nsamples = 20\nvalue = [0, 0, 14, 6, 0, 0]'),
#  Text(0.07910576096302666, 0.39473684210526316, 'fixed acidity <= 0.578\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.07566638005159071, 0.34210526315789475, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.0825451418744626, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09286328460877043, 0.39473684210526316, 'total sulfur dioxide <= 1.167\nentropy = 0.567\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.08942390369733448, 0.34210526315789475, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.09630266552020636, 0.34210526315789475, 'pH <= 0.037\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.09286328460877043, 0.2894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0997420464316423, 0.2894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.0825451418744626, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.117798796216681, 0.6052631578947368, 'chlorides <= -0.365\nentropy = 0.888\nsamples = 68\nvalue = [0, 5, 55, 8, 0, 0]'),
#  Text(0.10318142734307825, 0.5526315789473685, 'free sulfur dioxide <= -0.43\nentropy = 1.406\nsamples = 8\nvalue = [0, 3, 4, 1, 0, 0]'),
#  Text(0.09630266552020636, 0.5, 'citric acid <= 0.101\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.09286328460877043, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.0997420464316423, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11006018916595013, 0.5, 'residual sugar <= -0.384\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 1, 0, 0, 0]'),
#  Text(0.10662080825451418, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11349957007738606, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.13241616509028376, 0.5526315789473685, 'alcohol <= -1.267\nentropy = 0.724\nsamples = 60\nvalue = [0, 2, 51, 7, 0, 0]'),
#  Text(0.12381771281169389, 0.5, 'sulphates <= -1.213\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.12037833190025796, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.12725709372312985, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1410146173688736, 0.5, 'density <= 0.069\nentropy = 0.554\nsamples = 57\nvalue = [0, 1, 51, 5, 0, 0]'),
#  Text(0.13413585554600171, 0.4473684210526316, 'sulphates <= -0.777\nentropy = 0.738\nsamples = 24\nvalue = [0, 0, 19, 5, 0, 0]'),
#  Text(0.13069647463456577, 0.39473684210526316, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(0.13757523645743766, 0.39473684210526316, 'citric acid <= 0.152\nentropy = 1.0\nsamples = 10\nvalue = [0, 0, 5, 5, 0, 0]'),
#  Text(0.13413585554600171, 0.34210526315789475, 'total sulfur dioxide <= 0.773\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.13069647463456577, 0.2894736842105263, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.13757523645743766, 0.2894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1410146173688736, 0.34210526315789475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.14789337919174547, 0.4473684210526316, 'residual sugar <= 0.141\nentropy = 0.196\nsamples = 33\nvalue = [0, 1, 32, 0, 0, 0]'),
#  Text(0.14445399828030955, 0.39473684210526316, 'entropy = 0.0\nsamples = 29\nvalue = [0, 0, 29, 0, 0, 0]'),
#  Text(0.15133276010318142, 0.39473684210526316, 'sulphates <= -0.806\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.14789337919174547, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.15477214101461736, 0.34210526315789475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.19088564058469476, 0.6578947368421053, 'fixed acidity <= 1.384\nentropy = 1.348\nsamples = 61\nvalue = [0, 6, 32, 23, 0, 0]'),
#  Text(0.17540842648323302, 0.6052631578947368, 'pH <= -0.06\nentropy = 1.271\nsamples = 49\nvalue = [0, 3, 23, 23, 0, 0]'),
#  Text(0.16852966466036112, 0.5526315789473685, 'fixed acidity <= -0.56\nentropy = 0.988\nsamples = 39\nvalue = [0, 0, 22, 17, 0, 0]'),
#  Text(0.1650902837489252, 0.5, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.17196904557179707, 0.5, 'alcohol <= 0.031\nentropy = 0.997\nsamples = 32\nvalue = [0, 0, 15, 17, 0, 0]'),
#  Text(0.16852966466036112, 0.4473684210526316, 'pH <= -0.125\nentropy = 0.967\nsamples = 28\nvalue = [0, 0, 11, 17, 0, 0]'),
#  Text(0.1650902837489252, 0.39473684210526316, 'total sulfur dioxide <= 0.258\nentropy = 0.904\nsamples = 25\nvalue = [0, 0, 8, 17, 0, 0]'),
#  Text(0.16165090283748926, 0.34210526315789475, 'residual sugar <= -0.104\nentropy = 0.991\nsamples = 18\nvalue = [0, 0, 8, 10, 0, 0]'),
#  Text(0.15477214101461736, 0.2894736842105263, 'density <= -0.325\nentropy = 0.811\nsamples = 12\nvalue = [0, 0, 3, 9, 0, 0]'),
#  Text(0.15133276010318142, 0.23684210526315788, 'chlorides <= -0.302\nentropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.14789337919174547, 0.18421052631578946, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.15477214101461736, 0.18421052631578946, 'total sulfur dioxide <= -0.817\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.15133276010318142, 0.13157894736842105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1582115219260533, 0.13157894736842105, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1582115219260533, 0.23684210526315788, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.16852966466036112, 0.2894736842105263, 'free sulfur dioxide <= -1.112\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.1650902837489252, 0.23684210526315788, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17196904557179707, 0.23684210526315788, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.16852966466036112, 0.34210526315789475, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.17196904557179707, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17540842648323302, 0.4473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.1822871883061049, 0.5526315789473685, 'chlorides <= -0.493\nentropy = 1.295\nsamples = 10\nvalue = [0, 3, 1, 6, 0, 0]'),
#  Text(0.17884780739466896, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18572656921754085, 0.5, 'density <= 0.132\nentropy = 0.918\nsamples = 9\nvalue = [0, 3, 0, 6, 0, 0]'),
#  Text(0.1822871883061049, 0.4473684210526316, 'density <= -0.543\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 0, 6, 0, 0]'),
#  Text(0.17884780739466896, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.18572656921754085, 0.39473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.18916595012897677, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2063628546861565, 0.6052631578947368, 'density <= -0.091\nentropy = 0.811\nsamples = 12\nvalue = [0, 3, 9, 0, 0, 0]'),
#  Text(0.20292347377472056, 0.5526315789473685, 'density <= -0.358\nentropy = 1.0\nsamples = 6\nvalue = [0, 3, 3, 0, 0, 0]'),
#  Text(0.1994840928632846, 0.5, 'citric acid <= -0.769\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.19604471195184867, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.20292347377472056, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2063628546861565, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.20980223559759242, 0.5526315789473685, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.15154772141014616, 0.7105263157894737, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3342312446259673, 0.8157894736842105, 'fixed acidity <= -0.704\nentropy = 1.437\nsamples = 368\nvalue = [2, 6, 175, 163, 20, 2]'),
#  Text(0.24290627687016336, 0.7631578947368421, 'sulphates <= 0.094\nentropy = 1.538\nsamples = 92\nvalue = [0, 1, 26, 52, 11, 2]'),
#  Text(0.22012037833190026, 0.7105263157894737, 'chlorides <= 0.229\nentropy = 0.995\nsamples = 35\nvalue = [0, 0, 16, 19, 0, 0]'),
#  Text(0.21668099742046432, 0.6578947368421053, 'density <= -0.233\nentropy = 0.963\nsamples = 31\nvalue = [0, 0, 12, 19, 0, 0]'),
#  Text(0.21324161650902837, 0.6052631578947368, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.22012037833190026, 0.6052631578947368, 'residual sugar <= -0.489\nentropy = 0.877\nsamples = 27\nvalue = [0, 0, 8, 19, 0, 0]'),
#  Text(0.21668099742046432, 0.5526315789473685, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2235597592433362, 0.5526315789473685, 'chlorides <= -0.153\nentropy = 0.982\nsamples = 19\nvalue = [0, 0, 8, 11, 0, 0]'),
#  Text(0.21668099742046432, 0.5, 'residual sugar <= -0.349\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.21324161650902837, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.22012037833190026, 0.4473684210526316, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.23043852106620807, 0.5, 'total sulfur dioxide <= -0.756\nentropy = 0.811\nsamples = 12\nvalue = [0, 0, 3, 9, 0, 0]'),
#  Text(0.22699914015477213, 0.4473684210526316, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.23387790197764402, 0.4473684210526316, 'fixed acidity <= 0.024\nentropy = 0.985\nsamples = 7\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.23043852106620807, 0.39473684210526316, 'total sulfur dioxide <= 0.561\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.22699914015477213, 0.34210526315789475, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.23387790197764402, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23731728288907997, 0.39473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2235597592433362, 0.6578947368421053, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.2656921754084265, 0.7105263157894737, 'citric acid <= 0.383\nentropy = 1.627\nsamples = 57\nvalue = [0, 1, 10, 33, 11, 2]'),
#  Text(0.24419604471195186, 0.6578947368421053, 'chlorides <= -0.471\nentropy = 1.574\nsamples = 14\nvalue = [0, 0, 1, 5, 7, 1]'),
#  Text(0.23731728288907997, 0.6052631578947368, 'citric acid <= 0.203\nentropy = 1.5\nsamples = 4\nvalue = [0, 0, 1, 2, 0, 1]'),
#  Text(0.23387790197764402, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2407566638005159, 0.5526315789473685, 'free sulfur dioxide <= 0.251\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.23731728288907997, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.24419604471195186, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2510748065348237, 0.6052631578947368, 'alcohol <= -0.724\nentropy = 0.881\nsamples = 10\nvalue = [0, 0, 0, 3, 7, 0]'),
#  Text(0.24763542562338778, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.2545141874462597, 0.5526315789473685, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.2871883061049011, 0.6578947368421053, 'citric acid <= 2.046\nentropy = 1.446\nsamples = 43\nvalue = [0, 1, 9, 28, 4, 1]'),
#  Text(0.2751504729148753, 0.6052631578947368, 'chlorides <= -0.238\nentropy = 1.263\nsamples = 41\nvalue = [0, 1, 9, 28, 3, 0]'),
#  Text(0.26139294926913154, 0.5526315789473685, 'total sulfur dioxide <= 0.486\nentropy = 1.233\nsamples = 18\nvalue = [0, 1, 1, 13, 3, 0]'),
#  Text(0.2545141874462597, 0.5, 'sulphates <= 0.907\nentropy = 0.696\nsamples = 16\nvalue = [0, 0, 0, 13, 3, 0]'),
#  Text(0.2510748065348237, 0.4473684210526316, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2579535683576956, 0.4473684210526316, 'chlorides <= -0.567\nentropy = 0.954\nsamples = 8\nvalue = [0, 0, 0, 5, 3, 0]'),
#  Text(0.2545141874462597, 0.39473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.26139294926913154, 0.39473684210526316, 'density <= 1.765\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.2579535683576956, 0.34210526315789475, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.2648323301805675, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.26827171109200343, 0.5, 'free sulfur dioxide <= 0.349\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2648323301805675, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2717110920034394, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2889079965606191, 0.5526315789473685, 'total sulfur dioxide <= -0.847\nentropy = 0.932\nsamples = 23\nvalue = [0, 0, 8, 15, 0, 0]'),
#  Text(0.2820292347377472, 0.5, 'fixed acidity <= -0.814\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.27858985382631124, 0.4473684210526316, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.28546861564918313, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29578675838349094, 0.5, 'free sulfur dioxide <= 1.128\nentropy = 0.672\nsamples = 17\nvalue = [0, 0, 3, 14, 0, 0]'),
#  Text(0.292347377472055, 0.4473684210526316, 'pH <= 0.882\nentropy = 0.353\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(0.2889079965606191, 0.39473684210526316, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.29578675838349094, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2992261392949269, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2992261392949269, 0.6052631578947368, 'fixed acidity <= 1.074\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.29578675838349094, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.30266552020636284, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.42555621238177127, 0.7631578947368421, 'fixed acidity <= 0.958\nentropy = 1.326\nsamples = 276\nvalue = [2, 5, 149, 111, 9, 0]'),
#  Text(0.3610006448839209, 0.7105263157894737, 'pH <= -0.71\nentropy = 1.216\nsamples = 243\nvalue = [0, 4, 141, 92, 6, 0]'),
#  Text(0.3276010318142734, 0.6578947368421053, 'total sulfur dioxide <= -0.877\nentropy = 1.016\nsamples = 41\nvalue = [0, 3, 31, 7, 0, 0]'),
#  Text(0.3241616509028375, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3310404127257094, 0.6052631578947368, 'sulphates <= 5.467\nentropy = 0.928\nsamples = 39\nvalue = [0, 3, 31, 5, 0, 0]'),
#  Text(0.32158211521926056, 0.5526315789473685, 'chlorides <= 0.197\nentropy = 0.788\nsamples = 37\nvalue = [0, 2, 31, 4, 0, 0]'),
#  Text(0.3129836629406707, 0.5, 'residual sugar <= 0.001\nentropy = 1.384\nsamples = 12\nvalue = [0, 2, 7, 3, 0, 0]'),
#  Text(0.3061049011177988, 0.4473684210526316, 'fixed acidity <= 0.14\nentropy = 0.811\nsamples = 8\nvalue = [0, 2, 6, 0, 0, 0]'),
#  Text(0.30266552020636284, 0.39473684210526316, 'alcohol <= -0.96\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.2992261392949269, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.3061049011177988, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30954428202923473, 0.39473684210526316, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.31986242476354254, 0.4473684210526316, 'free sulfur dioxide <= 0.154\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.3164230438521066, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3233018056749785, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3301805674978504, 0.5, 'pH <= -2.562\nentropy = 0.242\nsamples = 25\nvalue = [0, 0, 24, 1, 0, 0]'),
#  Text(0.32674118658641443, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3336199484092863, 0.4473684210526316, 'entropy = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0, 0, 0]'),
#  Text(0.3404987102321582, 0.5526315789473685, 'alcohol <= -0.913\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.33705932932072225, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.34393809114359414, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.39440025795356837, 0.6578947368421053, 'density <= -0.325\nentropy = 1.192\nsamples = 202\nvalue = [0, 1, 110, 85, 6, 0]'),
#  Text(0.36113499570077384, 0.6052631578947368, 'total sulfur dioxide <= -1.013\nentropy = 1.087\nsamples = 42\nvalue = [0, 1, 15, 26, 0, 0]'),
#  Text(0.354256233877902, 0.5526315789473685, 'alcohol <= -0.583\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.35081685296646603, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3576956147893379, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.36801375752364573, 0.5526315789473685, 'residual sugar <= -0.209\nentropy = 0.918\nsamples = 39\nvalue = [0, 0, 13, 26, 0, 0]'),
#  Text(0.3645743766122098, 0.5, 'sulphates <= -0.167\nentropy = 0.981\nsamples = 31\nvalue = [0, 0, 13, 18, 0, 0]'),
#  Text(0.3576956147893379, 0.4473684210526316, 'sulphates <= -0.371\nentropy = 0.837\nsamples = 15\nvalue = [0, 0, 11, 4, 0, 0]'),
#  Text(0.354256233877902, 0.39473684210526316, 'free sulfur dioxide <= -0.43\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 5, 4, 0, 0]'),
#  Text(0.35081685296646603, 0.34210526315789475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3576956147893379, 0.34210526315789475, 'alcohol <= -0.441\nentropy = 0.918\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.354256233877902, 0.2894736842105263, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.36113499570077384, 0.2894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.36113499570077384, 0.39473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3714531384350817, 0.4473684210526316, 'total sulfur dioxide <= 0.031\nentropy = 0.544\nsamples = 16\nvalue = [0, 0, 2, 14, 0, 0]'),
#  Text(0.36801375752364573, 0.39473684210526316, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.3748925193465176, 0.39473684210526316, 'residual sugar <= -0.524\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3714531384350817, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.37833190025795355, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3714531384350817, 0.5, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.42766552020636284, 0.6052631578947368, 'citric acid <= 0.229\nentropy = 1.155\nsamples = 160\nvalue = [0, 0, 95, 59, 6, 0]'),
#  Text(0.4021926053310404, 0.5526315789473685, 'fixed acidity <= -0.91\nentropy = 1.155\nsamples = 132\nvalue = [0, 0, 72, 56, 4, 0]'),
#  Text(0.38521066208082544, 0.5, 'free sulfur dioxide <= 0.203\nentropy = 0.523\nsamples = 17\nvalue = [0, 0, 15, 2, 0, 0]'),
#  Text(0.3817712811693895, 0.4473684210526316, 'entropy = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.3886500429922614, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.41917454858125536, 0.5, 'free sulfur dioxide <= -0.723\nentropy = 1.183\nsamples = 115\nvalue = [0, 0, 57, 54, 4, 0]'),
#  Text(0.39552880481513325, 0.4473684210526316, 'chlorides <= 0.568\nentropy = 1.111\nsamples = 30\nvalue = [0, 0, 7, 21, 2, 0]'),
#  Text(0.3886500429922614, 0.39473684210526316, 'citric acid <= -1.153\nentropy = 0.84\nsamples = 26\nvalue = [0, 0, 7, 19, 0, 0]'),
#  Text(0.38521066208082544, 0.34210526315789475, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.39208942390369733, 0.34210526315789475, 'pH <= 0.2\nentropy = 0.964\nsamples = 18\nvalue = [0, 0, 7, 11, 0, 0]'),
#  Text(0.3886500429922614, 0.2894736842105263, 'free sulfur dioxide <= -1.112\nentropy = 0.837\nsamples = 15\nvalue = [0, 0, 4, 11, 0, 0]'),
#  Text(0.38521066208082544, 0.23684210526315788, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.39208942390369733, 0.23684210526315788, 'pH <= -0.32\nentropy = 0.414\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]'),
#  Text(0.3886500429922614, 0.18421052631578946, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39552880481513325, 0.18421052631578946, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.39552880481513325, 0.2894736842105263, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.40240756663800514, 0.39473684210526316, 'citric acid <= -0.564\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.3989681857265692, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4058469475494411, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.44282029234737746, 0.4473684210526316, 'chlorides <= 0.229\nentropy = 1.108\nsamples = 85\nvalue = [0, 0, 50, 33, 2, 0]'),
#  Text(0.43938091143594155, 0.39473684210526316, 'pH <= 1.434\nentropy = 1.131\nsamples = 79\nvalue = [0, 0, 44, 33, 2, 0]'),
#  Text(0.43594153052450557, 0.34210526315789475, 'density <= 0.224\nentropy = 1.15\nsamples = 73\nvalue = [0, 0, 38, 33, 2, 0]'),
#  Text(0.41616509028374893, 0.2894736842105263, 'citric acid <= -0.897\nentropy = 1.215\nsamples = 31\nvalue = [0, 0, 19, 10, 2, 0]'),
#  Text(0.4058469475494411, 0.23684210526315788, 'density <= 0.02\nentropy = 0.961\nsamples = 13\nvalue = [0, 0, 5, 8, 0, 0]'),
#  Text(0.40240756663800514, 0.18421052631578946, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.40928632846087704, 0.18421052631578946, 'sulphates <= 0.239\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.4058469475494411, 0.13157894736842105, 'pH <= 0.07\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.40240756663800514, 0.07894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.40928632846087704, 0.07894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.412725709372313, 0.13157894736842105, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.42648323301805674, 0.23684210526315788, 'total sulfur dioxide <= 0.773\nentropy = 0.986\nsamples = 18\nvalue = [0, 0, 14, 2, 2, 0]'),
#  Text(0.4230438521066208, 0.18421052631578946, 'chlorides <= -0.111\nentropy = 0.544\nsamples = 16\nvalue = [0, 0, 14, 0, 2, 0]'),
#  Text(0.41960447119518485, 0.13157894736842105, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.42648323301805674, 0.13157894736842105, 'total sulfur dioxide <= -0.105\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.4230438521066208, 0.07894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4299226139294927, 0.07894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4299226139294927, 0.18421052631578946, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.45571797076526227, 0.2894736842105263, 'sulphates <= -0.196\nentropy = 0.993\nsamples = 42\nvalue = [0, 0, 19, 23, 0, 0]'),
#  Text(0.4402407566638005, 0.23684210526315788, 'residual sugar <= -0.419\nentropy = 0.837\nsamples = 15\nvalue = [0, 0, 11, 4, 0, 0]'),
#  Text(0.43680137575236455, 0.18421052631578946, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.44368013757523644, 0.18421052631578946, 'alcohol <= -0.63\nentropy = 0.619\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.4402407566638005, 0.13157894736842105, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.4471195184866724, 0.13157894736842105, 'fixed acidity <= 0.422\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.44368013757523644, 0.07894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.45055889939810834, 0.07894736842105263, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.471195184866724, 0.23684210526315788, 'total sulfur dioxide <= 0.274\nentropy = 0.877\nsamples = 27\nvalue = [0, 0, 8, 19, 0, 0]'),
#  Text(0.46775580395528804, 0.18421052631578946, 'sulphates <= 0.094\nentropy = 0.982\nsamples = 19\nvalue = [0, 0, 8, 11, 0, 0]'),
#  Text(0.46087704213241615, 0.13157894736842105, 'fixed acidity <= 0.175\nentropy = 0.811\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.45743766122098023, 0.07894736842105263, 'residual sugar <= -0.559\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.45399828030954426, 0.02631578947368421, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.46087704213241615, 0.02631578947368421, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4643164230438521, 0.07894736842105263, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.47463456577815993, 0.13157894736842105, 'alcohol <= -0.441\nentropy = 0.684\nsamples = 11\nvalue = [0, 0, 2, 9, 0, 0]'),
#  Text(0.471195184866724, 0.07894736842105263, 'citric acid <= -0.001\nentropy = 0.469\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(0.46775580395528804, 0.02631578947368421, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.47463456577815993, 0.02631578947368421, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.47807394668959585, 0.07894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.47463456577815993, 0.18421052631578946, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.44282029234737746, 0.34210526315789475, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.44625967325881344, 0.39473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.4531384350816853, 0.5526315789473685, 'chlorides <= -0.524\nentropy = 0.85\nsamples = 28\nvalue = [0, 0, 23, 3, 2, 0]'),
#  Text(0.44969905417024936, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.45657781599312125, 0.5, 'pH <= -0.418\nentropy = 0.725\nsamples = 27\nvalue = [0, 0, 23, 3, 1, 0]'),
#  Text(0.4531384350816853, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.46001719690455717, 0.4473684210526316, 'free sulfur dioxide <= -0.723\nentropy = 0.516\nsamples = 26\nvalue = [0, 0, 23, 3, 0, 0]'),
#  Text(0.4531384350816853, 0.39473684210526316, 'total sulfur dioxide <= -0.711\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.44969905417024936, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.45657781599312125, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.46689595872742906, 0.39473684210526316, 'free sulfur dioxide <= 0.884\nentropy = 0.267\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.46345657781599314, 0.34210526315789475, 'entropy = 0.0\nsamples = 18\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.470335339638865, 0.34210526315789475, 'free sulfur dioxide <= 1.03\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.46689595872742906, 0.2894736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.47377472055030095, 0.2894736842105263, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4901117798796217, 0.7105263157894737, 'pH <= -1.685\nentropy = 1.667\nsamples = 33\nvalue = [2, 1, 8, 19, 3, 0]'),
#  Text(0.48065348237317285, 0.6578947368421053, 'residual sugar <= -0.559\nentropy = 0.918\nsamples = 6\nvalue = [0, 0, 4, 0, 2, 0]'),
#  Text(0.4772141014617369, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.48409286328460877, 0.6052631578947368, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.4995700773860705, 0.6578947368421053, 'chlorides <= 0.844\nentropy = 1.395\nsamples = 27\nvalue = [2, 1, 4, 19, 1, 0]'),
#  Text(0.49097162510748066, 0.6052631578947368, 'total sulfur dioxide <= -1.135\nentropy = 0.964\nsamples = 21\nvalue = [0, 0, 4, 16, 1, 0]'),
#  Text(0.48753224419604474, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4944110060189166, 0.5526315789473685, 'density <= 2.757\nentropy = 0.774\nsamples = 19\nvalue = [0, 0, 2, 16, 1, 0]'),
#  Text(0.48753224419604474, 0.5, 'chlorides <= 0.229\nentropy = 0.523\nsamples = 17\nvalue = [0, 0, 2, 15, 0, 0]'),
#  Text(0.48409286328460877, 0.4473684210526316, 'chlorides <= -0.546\nentropy = 0.337\nsamples = 16\nvalue = [0, 0, 1, 15, 0, 0]'),
#  Text(0.48065348237317285, 0.39473684210526316, 'residual sugar <= -0.349\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.4772141014617369, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.48409286328460877, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.48753224419604474, 0.39473684210526316, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.49097162510748066, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5012897678417885, 0.5, 'pH <= -0.775\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.49785038693035255, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5047291487532244, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5081685296646603, 0.6052631578947368, 'fixed acidity <= 1.191\nentropy = 1.459\nsamples = 6\nvalue = [2, 1, 0, 3, 0, 0]'),
#  Text(0.5047291487532244, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5116079105760963, 0.5526315789473685, 'free sulfur dioxide <= 1.858\nentropy = 0.918\nsamples = 3\nvalue = [2, 1, 0, 0, 0, 0]'),
#  Text(0.5081685296646603, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.5150472914875323, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5167669819432502, 0.868421052631579, 'residual sugar <= -0.664\nentropy = 0.437\nsamples = 90\nvalue = [0, 1, 84, 4, 1, 0]'),
#  Text(0.5133276010318143, 0.8157894736842105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5202063628546861, 0.8157894736842105, 'fixed acidity <= -1.309\nentropy = 0.353\nsamples = 89\nvalue = [0, 0, 84, 4, 1, 0]'),
#  Text(0.5116079105760963, 0.7631578947368421, 'fixed acidity <= -0.648\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.5081685296646603, 0.7105263157894737, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5150472914875323, 0.7105263157894737, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.528804815133276, 0.7631578947368421, 'sulphates <= 2.998\nentropy = 0.269\nsamples = 87\nvalue = [0, 0, 83, 4, 0, 0]'),
#  Text(0.5219260533104041, 0.7105263157894737, 'density <= -0.388\nentropy = 0.165\nsamples = 82\nvalue = [0, 0, 80, 2, 0, 0]'),
#  Text(0.5184866723989682, 0.6578947368421053, 'alcohol <= -0.536\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 7, 2, 0, 0]'),
#  Text(0.5150472914875323, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5219260533104041, 0.6052631578947368, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.5253654342218401, 0.6578947368421053, 'entropy = 0.0\nsamples = 73\nvalue = [0, 0, 73, 0, 0, 0]'),
#  Text(0.5356835769561479, 0.7105263157894737, 'alcohol <= -0.536\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.532244196044712, 0.6578947368421053, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5391229578675838, 0.6578947368421053, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7152031384350817, 0.9210526315789473, 'sulphates <= -0.429\nentropy = 1.745\nsamples = 427\nvalue = [3, 11, 71, 219, 113, 10]'),
#  Text(0.5917884780739467, 0.868421052631579, 'fixed acidity <= -0.924\nentropy = 1.848\nsamples = 107\nvalue = [3, 10, 35, 48, 11, 0]'),
#  Text(0.5494411006018917, 0.8157894736842105, 'chlorides <= -0.376\nentropy = 1.143\nsamples = 24\nvalue = [0, 1, 0, 15, 8, 0]'),
#  Text(0.5460017196904557, 0.7631578947368421, 'total sulfur dioxide <= -1.104\nentropy = 1.272\nsamples = 16\nvalue = [0, 1, 0, 7, 8, 0]'),
#  Text(0.5425623387790198, 0.7105263157894737, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.5494411006018917, 0.7105263157894737, 'residual sugar <= -0.139\nentropy = 1.241\nsamples = 11\nvalue = [0, 1, 0, 7, 3, 0]'),
#  Text(0.5460017196904557, 0.6578947368421053, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.5528804815133276, 0.6578947368421053, 'fixed acidity <= -1.199\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 0, 0, 3, 0]'),
#  Text(0.5494411006018917, 0.6052631578947368, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5563198624247635, 0.6052631578947368, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5528804815133276, 0.7631578947368421, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6341358555460017, 0.8157894736842105, 'fixed acidity <= 2.511\nentropy = 1.748\nsamples = 83\nvalue = [3, 9, 35, 33, 3, 0]'),
#  Text(0.6087704213241617, 0.7631578947368421, 'free sulfur dioxide <= -0.723\nentropy = 1.546\nsamples = 76\nvalue = [0, 7, 33, 33, 3, 0]'),
#  Text(0.5786758383490972, 0.7105263157894737, 'pH <= -0.645\nentropy = 1.68\nsamples = 38\nvalue = [0, 7, 19, 10, 2, 0]'),
#  Text(0.5666380051590714, 0.6578947368421053, 'citric acid <= 0.997\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.5631986242476354, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5700773860705073, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5907136715391229, 0.6578947368421053, 'pH <= 0.33\nentropy = 1.489\nsamples = 34\nvalue = [0, 7, 17, 10, 0, 0]'),
#  Text(0.5769561478933792, 0.6052631578947368, 'chlorides <= -0.142\nentropy = 1.384\nsamples = 12\nvalue = [0, 2, 3, 7, 0, 0]'),
#  Text(0.5735167669819432, 0.5526315789473685, 'sulphates <= -0.487\nentropy = 1.557\nsamples = 7\nvalue = [0, 2, 3, 2, 0, 0]'),
#  Text(0.5666380051590714, 0.5, 'chlorides <= -0.62\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.5631986242476354, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5700773860705073, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5803955288048152, 0.5, 'citric acid <= -0.513\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0, 0]'),
#  Text(0.5769561478933792, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5838349097162511, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5803955288048152, 0.5526315789473685, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.6044711951848667, 0.6052631578947368, 'fixed acidity <= 1.961\nentropy = 1.293\nsamples = 22\nvalue = [0, 5, 14, 3, 0, 0]'),
#  Text(0.6010318142734308, 0.5526315789473685, 'fixed acidity <= 0.093\nentropy = 1.076\nsamples = 20\nvalue = [0, 5, 14, 1, 0, 0]'),
#  Text(0.5941530524505589, 0.5, 'sulphates <= -0.632\nentropy = 1.371\nsamples = 5\nvalue = [0, 3, 1, 1, 0, 0]'),
#  Text(0.5907136715391229, 0.4473684210526316, 'fixed acidity <= -0.484\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.587274290627687, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5941530524505589, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5975924333619949, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.6079105760963026, 0.5, 'total sulfur dioxide <= -1.119\nentropy = 0.567\nsamples = 15\nvalue = [0, 2, 13, 0, 0, 0]'),
#  Text(0.6044711951848667, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6113499570077386, 0.4473684210526316, 'sulphates <= -0.545\nentropy = 0.371\nsamples = 14\nvalue = [0, 1, 13, 0, 0, 0]'),
#  Text(0.6079105760963026, 0.39473684210526316, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.6147893379191746, 0.39473684210526316, 'total sulfur dioxide <= -0.998\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.6113499570077386, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6182287188306105, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6079105760963026, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6388650042992261, 0.7105263157894737, 'alcohol <= 0.692\nentropy = 1.107\nsamples = 38\nvalue = [0, 0, 14, 23, 1, 0]'),
#  Text(0.6319862424763543, 0.6578947368421053, 'sulphates <= -0.487\nentropy = 0.971\nsamples = 20\nvalue = [0, 0, 12, 8, 0, 0]'),
#  Text(0.6285468615649183, 0.6052631578947368, 'alcohol <= 0.408\nentropy = 0.874\nsamples = 17\nvalue = [0, 0, 12, 5, 0, 0]'),
#  Text(0.6251074806534824, 0.5526315789473685, 'fixed acidity <= 0.368\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.6216680997420464, 0.5, 'density <= -1.635\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.6182287188306105, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6251074806534824, 0.4473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6285468615649183, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.6319862424763543, 0.5526315789473685, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.6354256233877902, 0.6052631578947368, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.645743766122098, 0.6578947368421053, 'pH <= 1.109\nentropy = 0.803\nsamples = 18\nvalue = [0, 0, 2, 15, 1, 0]'),
#  Text(0.6423043852106621, 0.6052631578947368, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.649183147033534, 0.6052631578947368, 'density <= -1.565\nentropy = 1.459\nsamples = 6\nvalue = [0, 0, 2, 3, 1, 0]'),
#  Text(0.645743766122098, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6526225279449699, 0.5526315789473685, 'free sulfur dioxide <= 1.322\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.649183147033534, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6560619088564058, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6595012897678418, 0.7631578947368421, 'chlorides <= -0.089\nentropy = 1.557\nsamples = 7\nvalue = [3, 2, 2, 0, 0, 0]'),
#  Text(0.6560619088564058, 0.7105263157894737, 'total sulfur dioxide <= -0.877\nentropy = 1.0\nsamples = 4\nvalue = [0, 2, 2, 0, 0, 0]'),
#  Text(0.6526225279449699, 0.6578947368421053, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6595012897678418, 0.6578947368421053, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.6629406706792778, 0.7105263157894737, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]'),
#  Text(0.8386177987962167, 0.868421052631579, 'alcohol <= 1.069\nentropy = 1.546\nsamples = 320\nvalue = [0, 1, 36, 171, 102, 10]'),
#  Text(0.7463456577815993, 0.8157894736842105, 'fixed acidity <= -0.869\nentropy = 1.399\nsamples = 195\nvalue = [0, 1, 31, 124, 37, 2]'),
#  Text(0.7037833190025795, 0.7631578947368421, 'pH <= -0.418\nentropy = 1.647\nsamples = 70\nvalue = [0, 0, 13, 31, 24, 2]'),
#  Text(0.6801375752364575, 0.7105263157894737, 'fixed acidity <= 1.249\nentropy = 1.472\nsamples = 25\nvalue = [0, 0, 1, 8, 14, 2]'),
#  Text(0.6732588134135855, 0.6578947368421053, 'density <= -0.803\nentropy = 1.239\nsamples = 13\nvalue = [0, 0, 0, 8, 4, 1]'),
#  Text(0.6698194325021496, 0.6052631578947368, 'citric acid <= 0.203\nentropy = 1.252\nsamples = 6\nvalue = [0, 0, 0, 1, 4, 1]'),
#  Text(0.6663800515907137, 0.5526315789473685, 'chlorides <= -0.524\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.6629406706792778, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6698194325021496, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6732588134135855, 0.5526315789473685, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.6766981943250215, 0.6052631578947368, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.6870163370593293, 0.6578947368421053, 'fixed acidity <= -1.199\nentropy = 0.817\nsamples = 12\nvalue = [0, 0, 1, 0, 10, 1]'),
#  Text(0.6835769561478934, 0.6052631578947368, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 10, 0]'),
#  Text(0.6904557179707652, 0.6052631578947368, 'sulphates <= -0.167\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.6870163370593293, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6938950988822012, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7274290627687017, 0.7105263157894737, 'total sulfur dioxide <= 0.289\nentropy = 1.486\nsamples = 45\nvalue = [0, 0, 12, 23, 10, 0]'),
#  Text(0.7128116938950989, 0.6578947368421053, 'total sulfur dioxide <= -0.711\nentropy = 1.327\nsamples = 34\nvalue = [0, 0, 5, 21, 8, 0]'),
#  Text(0.704213241616509, 0.6052631578947368, 'sulphates <= 0.791\nentropy = 1.566\nsamples = 15\nvalue = [0, 0, 5, 6, 4, 0]'),
#  Text(0.7007738607050731, 0.5526315789473685, 'alcohol <= 0.786\nentropy = 1.495\nsamples = 11\nvalue = [0, 0, 5, 2, 4, 0]'),
#  Text(0.6973344797936372, 0.5, 'alcohol <= 0.408\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 5, 0, 4, 0]'),
#  Text(0.6938950988822012, 0.4473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7007738607050731, 0.4473684210526316, 'density <= -1.184\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.6973344797936372, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.704213241616509, 0.39473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.704213241616509, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7076526225279449, 0.5526315789473685, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7214101461736887, 0.6052631578947368, 'sulphates <= 0.907\nentropy = 0.742\nsamples = 19\nvalue = [0, 0, 0, 15, 4, 0]'),
#  Text(0.7145313843508169, 0.5526315789473685, 'chlorides <= -0.694\nentropy = 0.353\nsamples = 15\nvalue = [0, 0, 0, 14, 1, 0]'),
#  Text(0.711092003439381, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7179707652622528, 0.5, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.7282889079965607, 0.5526315789473685, 'citric acid <= 1.022\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.7248495270851246, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.7317282889079966, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7420464316423044, 0.6578947368421053, 'fixed acidity <= -0.064\nentropy = 1.309\nsamples = 11\nvalue = [0, 0, 7, 2, 2, 0]'),
#  Text(0.7386070507308684, 0.6052631578947368, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.7454858125537404, 0.6052631578947368, 'fixed acidity <= -1.062\nentropy = 1.522\nsamples = 5\nvalue = [0, 0, 1, 2, 2, 0]'),
#  Text(0.7420464316423044, 0.5526315789473685, 'pH <= -0.093\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.7386070507308684, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7454858125537404, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7489251934651763, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.788907996560619, 0.7631578947368421, 'density <= -0.211\nentropy = 1.115\nsamples = 125\nvalue = [0, 1, 18, 93, 13, 0]'),
#  Text(0.7626827171109201, 0.7105263157894737, 'fixed acidity <= -1.494\nentropy = 0.645\nsamples = 71\nvalue = [0, 0, 7, 62, 2, 0]'),
#  Text(0.7592433361994841, 0.6578947368421053, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.766122098022356, 0.6578947368421053, 'total sulfur dioxide <= -0.59\nentropy = 0.512\nsamples = 68\nvalue = [0, 0, 4, 62, 2, 0]'),
#  Text(0.7592433361994841, 0.6052631578947368, 'alcohol <= 0.149\nentropy = 0.353\nsamples = 30\nvalue = [0, 0, 0, 28, 2, 0]'),
#  Text(0.7558039552880481, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7626827171109201, 0.5526315789473685, 'pH <= -0.807\nentropy = 0.216\nsamples = 29\nvalue = [0, 0, 0, 28, 1, 0]'),
#  Text(0.7592433361994841, 0.5, 'density <= -0.521\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7558039552880481, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7626827171109201, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.766122098022356, 0.5, 'entropy = 0.0\nsamples = 26\nvalue = [0, 0, 0, 26, 0, 0]'),
#  Text(0.7730008598452278, 0.6052631578947368, 'chlorides <= -0.662\nentropy = 0.485\nsamples = 38\nvalue = [0, 0, 4, 34, 0, 0]'),
#  Text(0.7695614789337919, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7764402407566638, 0.5526315789473685, 'total sulfur dioxide <= 1.773\nentropy = 0.31\nsamples = 36\nvalue = [0, 0, 2, 34, 0, 0]'),
#  Text(0.7730008598452278, 0.5, 'fixed acidity <= 0.862\nentropy = 0.187\nsamples = 35\nvalue = [0, 0, 1, 34, 0, 0]'),
#  Text(0.7695614789337919, 0.4473684210526316, 'entropy = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.7764402407566638, 0.4473684210526316, 'chlorides <= -0.217\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.7730008598452278, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7798796216680998, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7798796216680998, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8151332760103182, 0.7105263157894737, 'pH <= 0.037\nentropy = 1.501\nsamples = 54\nvalue = [0, 1, 11, 31, 11, 0]'),
#  Text(0.7953568357695615, 0.6578947368421053, 'citric acid <= 0.434\nentropy = 1.225\nsamples = 36\nvalue = [0, 0, 10, 23, 3, 0]'),
#  Text(0.7919174548581256, 0.6052631578947368, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7987962166809974, 0.6052631578947368, 'residual sugar <= 0.246\nentropy = 1.115\nsamples = 32\nvalue = [0, 0, 6, 23, 3, 0]'),
#  Text(0.7901977644024075, 0.5526315789473685, 'sulphates <= 0.994\nentropy = 0.454\nsamples = 21\nvalue = [0, 0, 2, 19, 0, 0]'),
#  Text(0.7867583834909716, 0.5, 'chlorides <= 0.399\nentropy = 0.286\nsamples = 20\nvalue = [0, 0, 1, 19, 0, 0]'),
#  Text(0.7833190025795357, 0.4473684210526316, 'entropy = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.7901977644024075, 0.4473684210526316, 'chlorides <= 0.568\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.7867583834909716, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7936371453138436, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7936371453138436, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8073946689595872, 0.5526315789473685, 'alcohol <= 0.503\nentropy = 1.573\nsamples = 11\nvalue = [0, 0, 4, 4, 3, 0]'),
#  Text(0.8039552880481513, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8108340498710233, 0.5, 'fixed acidity <= -0.21\nentropy = 1.392\nsamples = 9\nvalue = [0, 0, 4, 4, 1, 0]'),
#  Text(0.8039552880481513, 0.4473684210526316, 'free sulfur dioxide <= 1.225\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.8005159071367154, 0.39473684210526316, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8073946689595872, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8177128116938951, 0.4473684210526316, 'residual sugar <= 0.982\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.8142734307824592, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.821152192605331, 0.39473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8349097162510748, 0.6578947368421053, 'total sulfur dioxide <= 0.773\nentropy = 1.503\nsamples = 18\nvalue = [0, 1, 1, 8, 8, 0]'),
#  Text(0.828030954428203, 0.6052631578947368, 'residual sugar <= -0.139\nentropy = 1.0\nsamples = 16\nvalue = [0, 0, 0, 8, 8, 0]'),
#  Text(0.8245915735167669, 0.5526315789473685, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8314703353396389, 0.5526315789473685, 'pH <= 0.525\nentropy = 0.918\nsamples = 12\nvalue = [0, 0, 0, 4, 8, 0]'),
#  Text(0.828030954428203, 0.5, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.8349097162510748, 0.5, 'alcohol <= 0.503\nentropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.8314703353396389, 0.4473684210526316, 'pH <= 1.207\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.828030954428203, 0.39473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8349097162510748, 0.39473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8383490971625107, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8417884780739467, 0.6052631578947368, 'pH <= 0.622\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8383490971625107, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8452278589853827, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.930889939810834, 0.8157894736842105, 'total sulfur dioxide <= -0.105\nentropy = 1.461\nsamples = 125\nvalue = [0, 0, 5, 47, 65, 8]'),
#  Text(0.8927343078245916, 0.7631578947368421, 'fixed acidity <= -0.594\nentropy = 1.25\nsamples = 87\nvalue = [0, 0, 1, 26, 55, 5]'),
#  Text(0.8628546861564919, 0.7105263157894737, 'citric acid <= 0.178\nentropy = 0.991\nsamples = 52\nvalue = [0, 0, 0, 8, 40, 4]'),
#  Text(0.8521066208082545, 0.6578947368421053, 'density <= -2.282\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.8486672398968186, 0.6052631578947368, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8555460017196904, 0.6052631578947368, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8736027515047291, 0.6578947368421053, 'fixed acidity <= -1.034\nentropy = 0.882\nsamples = 48\nvalue = [0, 0, 0, 5, 39, 4]'),
#  Text(0.8624247635425624, 0.6052631578947368, 'density <= 0.387\nentropy = 0.229\nsamples = 27\nvalue = [0, 0, 0, 0, 26, 1]'),
#  Text(0.8589853826311264, 0.5526315789473685, 'entropy = 0.0\nsamples = 26\nvalue = [0, 0, 0, 0, 26, 0]'),
#  Text(0.8658641444539983, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.884780739466896, 0.6052631578947368, 'pH <= 0.2\nentropy = 1.322\nsamples = 21\nvalue = [0, 0, 0, 5, 13, 3]'),
#  Text(0.8727429062768701, 0.5526315789473685, 'residual sugar <= -0.279\nentropy = 0.906\nsamples = 15\nvalue = [0, 0, 0, 2, 12, 1]'),
#  Text(0.8658641444539983, 0.5, 'fixed acidity <= 0.637\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.8624247635425624, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8693035253654342, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8796216680997421, 0.5, 'chlorides <= 0.664\nentropy = 0.391\nsamples = 13\nvalue = [0, 0, 0, 1, 12, 0]'),
#  Text(0.8761822871883062, 0.4473684210526316, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 12, 0]'),
#  Text(0.883061049011178, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8968185726569218, 0.5526315789473685, 'fixed acidity <= -0.268\nentropy = 1.459\nsamples = 6\nvalue = [0, 0, 0, 3, 1, 2]'),
#  Text(0.8933791917454859, 0.5, 'alcohol <= 2.438\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.8899398108340498, 0.4473684210526316, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8968185726569218, 0.4473684210526316, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9002579535683577, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9226139294926913, 0.7105263157894737, 'alcohol <= 2.485\nentropy = 1.31\nsamples = 35\nvalue = [0, 0, 1, 18, 15, 1]'),
#  Text(0.9140154772141015, 0.6578947368421053, 'free sulfur dioxide <= -0.187\nentropy = 1.173\nsamples = 31\nvalue = [0, 0, 1, 15, 15, 0]'),
#  Text(0.9071367153912295, 0.6052631578947368, 'density <= -1.41\nentropy = 0.976\nsamples = 22\nvalue = [0, 0, 0, 9, 13, 0]'),
#  Text(0.9036973344797936, 0.5526315789473685, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.9105760963026656, 0.5526315789473685, 'chlorides <= -0.386\nentropy = 0.989\nsamples = 16\nvalue = [0, 0, 0, 9, 7, 0]'),
#  Text(0.9071367153912295, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9140154772141015, 0.5, 'sulphates <= 1.314\nentropy = 0.946\nsamples = 11\nvalue = [0, 0, 0, 4, 7, 0]'),
#  Text(0.9105760963026656, 0.4473684210526316, 'residual sugar <= 1.122\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 0, 2, 7, 0]'),
#  Text(0.9071367153912295, 0.39473684210526316, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.9140154772141015, 0.39473684210526316, 'pH <= -1.197\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.9105760963026656, 0.34210526315789475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9174548581255374, 0.34210526315789475, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9174548581255374, 0.4473684210526316, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9208942390369733, 0.6052631578947368, 'residual sugar <= -0.069\nentropy = 1.224\nsamples = 9\nvalue = [0, 0, 1, 6, 2, 0]'),
#  Text(0.9174548581255374, 0.5526315789473685, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.9243336199484092, 0.5526315789473685, 'sulphates <= 0.152\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.9208942390369733, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9277730008598453, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9312123817712812, 0.6578947368421053, 'pH <= -0.97\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1]'),
#  Text(0.9277730008598453, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9346517626827171, 0.6052631578947368, 'density <= -0.015\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.9312123817712812, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.938091143594153, 0.5526315789473685, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9690455717970765, 0.7631578947368421, 'total sulfur dioxide <= 0.849\nentropy = 1.611\nsamples = 38\nvalue = [0, 0, 4, 21, 10, 3]'),
#  Text(0.9518486672398968, 0.7105263157894737, 'free sulfur dioxide <= 1.42\nentropy = 1.208\nsamples = 24\nvalue = [0, 0, 2, 18, 2, 2]'),
#  Text(0.944969905417025, 0.6578947368421053, 'alcohol <= 2.202\nentropy = 0.523\nsamples = 17\nvalue = [0, 0, 2, 15, 0, 0]'),
#  Text(0.9415305245055889, 0.6052631578947368, 'entropy = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.9484092863284609, 0.6052631578947368, 'density <= -2.097\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.944969905417025, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9518486672398968, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9587274290627688, 0.6578947368421053, 'sulphates <= 0.53\nentropy = 1.557\nsamples = 7\nvalue = [0, 0, 0, 3, 2, 2]'),
#  Text(0.9552880481513327, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9621668099742047, 0.6052631578947368, 'free sulfur dioxide <= 2.102\nentropy = 0.971\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.9587274290627688, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9656061908856406, 0.5526315789473685, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9862424763542562, 0.7105263157894737, 'fixed acidity <= 0.12\nentropy = 1.611\nsamples = 14\nvalue = [0, 0, 2, 3, 8, 1]'),
#  Text(0.9793637145313844, 0.6578947368421053, 'sulphates <= 0.21\nentropy = 1.096\nsamples = 11\nvalue = [0, 0, 2, 1, 8, 0]'),
#  Text(0.9759243336199485, 0.6052631578947368, 'free sulfur dioxide <= 0.203\nentropy = 1.5\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.9724849527085124, 0.5526315789473685, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9793637145313844, 0.5526315789473685, 'residual sugar <= 0.281\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.9759243336199485, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9828030954428203, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9828030954428203, 0.6052631578947368, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.9931212381771282, 0.6578947368421053, 'fixed acidity <= 1.302\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1]'),
#  Text(0.9896818572656921, 0.6052631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9965606190885641, 0.6052631578947368, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]')]
